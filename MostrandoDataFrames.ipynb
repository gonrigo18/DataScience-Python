# %%
import pandas as pd

# %%
df_17 = pd.read_csv('17.csv')

# %%
df_17
# Out:
#           NENVIO       FECHA     REFERENCIA  REF_ADICIONAL OBSER1 OBSER2  \
# 0     1089280830  02/02/2023  000502482638R     82969368.0    NaN    NaN
# 1     1089304773  06/02/2023  000502483023R     82969763.0    NaN    NaN
# 2     1089337521  01/02/2023  000502483732R     82970536.0    NaN    NaN
# 3     1089337522  01/02/2023  000502483733R     82970537.0    NaN    NaN
# 4     1089337523  01/02/2023  000502483734R     82970538.0    NaN    NaN
# ...          ...         ...            ...            ...    ...    ...
# 8778  1089775292  17/02/2023     0082977669            NaN    NaN    NaN
# 8779  1089775513  17/02/2023     0082977636            NaN    NaN    NaN
# 8780  1089775540  17/02/2023     0082977675            NaN    NaN    NaN
# 8781  1089775762  17/02/2023     0082978028            NaN    NaN    NaN
# 8782  1089775771  17/02/2023     0082977536            NaN    NaN    NaN
#
#        CODREMI            CLIENTE                       ORIGEN  \
# ...

# %%
# Mostrar las 5 primeras filas
df_17.head()
# Out:
#        NENVIO       FECHA     REFERENCIA  REF_ADICIONAL OBSER1 OBSER2  \
# 0  1089280830  02/02/2023  000502482638R     82969368.0    NaN    NaN
# 1  1089304773  06/02/2023  000502483023R     82969763.0    NaN    NaN
# 2  1089337521  01/02/2023  000502483732R     82970536.0    NaN    NaN
# 3  1089337522  01/02/2023  000502483733R     82970537.0    NaN    NaN
# 4  1089337523  01/02/2023  000502483734R     82970538.0    NaN    NaN
#
#     CODREMI            CLIENTE                  ORIGEN  \
# 0  60009400  ROFINA S.A.I.C.F.  WH MALVINAS ARGENTINAS
# 1  60009400  ROFINA S.A.I.C.F.  WH MALVINAS ARGENTINAS
# 2  60009400  ROFINA S.A.I.C.F.  WH MALVINAS ARGENTINAS
# 3  60009400  ROFINA S.A.I.C.F.  WH MALVINAS ARGENTINAS
# 4  60009400  ROFINA S.A.I.C.F.  WH MALVINAS ARGENTINAS
#
#                   DESTINO  ...  VALOR DECLARADO  KEYTSV             SITUACION  \
# 0  WH MALVINAS ARGENTINAS  ...             4.00       6  PENDIENTE EN DESTINO
# ...

# %%
# Mostrar las 5 ultimas filas
df_17.tail()
# Out:
#           NENVIO       FECHA  REFERENCIA  REF_ADICIONAL OBSER1 OBSER2  \
# 8778  1089775292  17/02/2023  0082977669            NaN    NaN    NaN
# 8779  1089775513  17/02/2023  0082977636            NaN    NaN    NaN
# 8780  1089775540  17/02/2023  0082977675            NaN    NaN    NaN
# 8781  1089775762  17/02/2023  0082978028            NaN    NaN    NaN
# 8782  1089775771  17/02/2023  0082977536            NaN    NaN    NaN
#
#        CODREMI            CLIENTE                       ORIGEN  \
# 8778  60009400  ROFINA S.A.I.C.F.  AVELLANEDA - C DISTRIBUCIÓN
# 8779  60009400  ROFINA S.A.I.C.F.  AVELLANEDA - C DISTRIBUCIÓN
# 8780  60009400  ROFINA S.A.I.C.F.  AVELLANEDA - C DISTRIBUCIÓN
# 8781  60009400  ROFINA S.A.I.C.F.  AVELLANEDA - C DISTRIBUCIÓN
# 8782  60009400  ROFINA S.A.I.C.F.  AVELLANEDA - C DISTRIBUCIÓN
#
#                           DESTINO  ...  VALOR DECLARADO  KEYTSV    SITUACION  \
# 8778  AVELLANEDA - C DISTRIBUCIÓN  ...              1.0      47  PDTE.ORIGEN
# ...

# %%
# Mostrar N filas
pd.set_option('display.max_rows', 10)
df_17
# Out:
#           NENVIO       FECHA     REFERENCIA  REF_ADICIONAL OBSER1 OBSER2  \
# 0     1089280830  02/02/2023  000502482638R     82969368.0    NaN    NaN
# 1     1089304773  06/02/2023  000502483023R     82969763.0    NaN    NaN
# 2     1089337521  01/02/2023  000502483732R     82970536.0    NaN    NaN
# 3     1089337522  01/02/2023  000502483733R     82970537.0    NaN    NaN
# 4     1089337523  01/02/2023  000502483734R     82970538.0    NaN    NaN
# ...          ...         ...            ...            ...    ...    ...
# 8778  1089775292  17/02/2023     0082977669            NaN    NaN    NaN
# 8779  1089775513  17/02/2023     0082977636            NaN    NaN    NaN
# 8780  1089775540  17/02/2023     0082977675            NaN    NaN    NaN
# 8781  1089775762  17/02/2023     0082978028            NaN    NaN    NaN
# 8782  1089775771  17/02/2023     0082977536            NaN    NaN    NaN
#
#        CODREMI            CLIENTE                       ORIGEN  \
# ...

# %%
# Accediendo al atributo shape
df_17.shape # Numero de filas y de columnas
# Out:
# (8783, 42)

# %%
# Acceso atributo index
df_17.index
# Out:
# RangeIndex(start=0, stop=8783, step=1)

# %%
# Acceso al atributo columns
df_17.columns
# Out:
# Index(['NENVIO', 'FECHA', 'REFERENCIA', 'REF_ADICIONAL', 'OBSER1', 'OBSER2',
#        'CODREMI', 'CLIENTE', 'ORIGEN', 'DESTINO', 'CP_ORI', 'CP_DES',
#        'F_RECOGIDA', 'F_PACTADA', 'HORA_EA_DESDE', 'HORA_EA_HASTA',
#        'F_CIERRE_SALIDA', 'FECHA LLEGADA', 'FECHA ASIGNACION', 'F_ENTREGA',
#        'F_DEVOLUCION', 'USUARIO_B', 'NOMBRE_DEST', 'DOMICILIO_DES',
#        'LOCALIDAD_DES', 'PEDIDO_CERRADO_CC', 'BULTOS', 'PALETS', 'KILOS',
#        'KILOS AFORADOS', 'VOLUMEN', 'GESTION COBRANZAS', 'VALOR DECLARADO',
#        'KEYTSV', 'SITUACION', 'CENTRO_COSTO', 'USUARIO_G', 'FEC_MOBILE',
#        'FEC_MOBILE_2115', 'FEC_MOBILE_CDS', 'CENTRO_COSTO_1', 'UCA'],
#       dtype='object')

# %%
# Tipo de dato de cada columna
df_17.dtypes
# Out:
# NENVIO               int64
# FECHA               object
# REFERENCIA          object
# REF_ADICIONAL      float64
# OBSER1              object
#                     ...
# FEC_MOBILE          object
# FEC_MOBILE_2115     object
# FEC_MOBILE_CDS      object
# CENTRO_COSTO_1      object
# UCA                 object
# Length: 42, dtype: object

# %%
# Obtener informacion sobre el DataFrame
df_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8783 entries, 0 to 8782
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   NENVIO             8783 non-null   int64
#  1   FECHA              8783 non-null   object
#  2   REFERENCIA         8783 non-null   object
#  3   REF_ADICIONAL      6933 non-null   float64
#  4   OBSER1             969 non-null    object
#  5   OBSER2             223 non-null    object
#  6   CODREMI            8783 non-null   int64
#  7   CLIENTE            8783 non-null   object
#  8   ORIGEN             8783 non-null   object
#  9   DESTINO            8783 non-null   object
#  10  CP_ORI             8783 non-null   int64
#  11  CP_DES             8783 non-null   int64
#  12  F_RECOGIDA         8783 non-null   object
#  13  F_PACTADA          4323 non-null   object
#  14  HORA_EA_DESDE      16 non-null     object
#  15  HORA_EA_HASTA      16 non-null     object
# ...

# %%
# Obtener valores estadisticos del DataFrame
df_17.describe()
# Out:
#              NENVIO  REF_ADICIONAL       CODREMI       CP_ORI       CP_DES  \
# count  8.783000e+03   6.933000e+03  8.783000e+03  8783.000000  8783.000000
# mean   1.089590e+09   8.291993e+07  1.576161e+08  1680.176250  3190.862234
# std    1.035016e+05   1.993541e+06  2.867705e+08   582.682448  2170.771753
# min    1.089281e+09   1.328080e+05  4.008031e+06  1001.000000  1001.000000
# 25%    1.089494e+09   8.297290e+07  6.000940e+07  1614.000000  1605.000000
# 50%    1.089587e+09   8.297450e+07  6.000940e+07  1614.000000  1878.000000
# 75%    1.089675e+09   8.297626e+07  6.000940e+07  1614.000000  5004.000000
# max    1.089776e+09   8.297804e+07  1.000000e+09  9420.000000  9420.000000
#
#             BULTOS       PALETS         KILOS  KILOS AFORADOS      VOLUMEN  \
# count  8783.000000  8783.000000   8783.000000     8783.000000  8783.000000
# mean      3.491290     0.035182     64.336279      219.470290     0.537849
# ...

# %%
# Funciones

# %%
# Obtener el tamaño del DataFrame (filas)
len(df_17)
# Out:
# 8783

# %%
# Obtener el maximo index
max(df_17.index)
# Out:
# 8782

# %%
# obtener el minimo index
min(df_17.index)
# Out:
# 0

# %%
# obtener el tipo de dato del dataframe
type(df_17)
# Out:
# pandas.core.frame.DataFrame

# %%
# redondear los valores del dataframe
round(df_17,2)
# Out:
#           NENVIO       FECHA     REFERENCIA  REF_ADICIONAL OBSER1 OBSER2  \
# 0     1089280830  02/02/2023  000502482638R     82969368.0    NaN    NaN
# 1     1089304773  06/02/2023  000502483023R     82969763.0    NaN    NaN
# 2     1089337521  01/02/2023  000502483732R     82970536.0    NaN    NaN
# 3     1089337522  01/02/2023  000502483733R     82970537.0    NaN    NaN
# 4     1089337523  01/02/2023  000502483734R     82970538.0    NaN    NaN
# ...          ...         ...            ...            ...    ...    ...
# 8778  1089775292  17/02/2023     0082977669            NaN    NaN    NaN
# 8779  1089775513  17/02/2023     0082977636            NaN    NaN    NaN
# 8780  1089775540  17/02/2023     0082977675            NaN    NaN    NaN
# 8781  1089775762  17/02/2023     0082978028            NaN    NaN    NaN
# 8782  1089775771  17/02/2023     0082977536            NaN    NaN    NaN
#
#        CODREMI            CLIENTE                       ORIGEN  \
# ...

# %%
# seleccionar una columna de un dataframe
df_17['SITUACION']
# Out:
# 0       PENDIENTE EN DESTINO
# 1                  ENTREGADO
# 2                  ENTREGADO
# 3                  ENTREGADO
# 4                  ENTREGADO
#                 ...
# 8778             PDTE.ORIGEN
# 8779             PDTE.ORIGEN
# 8780             PDTE.ORIGEN
# 8781             PDTE.ORIGEN
# 8782             PDTE.ORIGEN
# Name: SITUACION, Length: 8783, dtype: object

# %%
# Filtrar por valor de la columna
df_17['SITUACION'] == 'PDTE.ORIGEN'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8778     True
# 8779     True
# 8780     True
# 8781     True
# 8782     True
# Name: SITUACION, Length: 8783, dtype: bool

# %%
# revisar el tipo de dato de una columna
type(df_17['SITUACION'] == 'PDTE.ORIGEN')
# Out:
# pandas.core.series.Series

# %%
# series: atributos y metodos
df_17['SITUACION'].index
df_17['SITUACION'].head()
# Out:
# 0    PENDIENTE EN DESTINO
# 1               ENTREGADO
# 2               ENTREGADO
# 3               ENTREGADO
# 4               ENTREGADO
# Name: SITUACION, dtype: object

# %%
# Seleccionar una columna con .
df_17.SITUACION
# Out:
# 0       PENDIENTE EN DESTINO
# 1                  ENTREGADO
# 2                  ENTREGADO
# 3                  ENTREGADO
# 4                  ENTREGADO
#                 ...
# 8778             PDTE.ORIGEN
# 8779             PDTE.ORIGEN
# 8780             PDTE.ORIGEN
# 8781             PDTE.ORIGEN
# 8782             PDTE.ORIGEN
# Name: SITUACION, Length: 8783, dtype: object

# %%
df_origen = df_17['SITUACION'] == 'PDTE.ORIGEN' # Guardamos los valores PDTE.ORIGEN de la columna SITUACION en otro dataframe
filtered_df = df_17[df_origen] # filtramos

# %%
filtered_df.shape
# Out:
# (745, 42)

# %%
 # Seleccionar dos o mas columnas
filtered_df[['NENVIO','FECHA','DESTINO']]
# Out:
#           NENVIO       FECHA                      DESTINO
# 215   1089428919  01/02/2023                      ROSARIO
# 383   1089429294  01/02/2023       WH MALVINAS ARGENTINAS
# 609   1089436347  01/02/2023       WH MALVINAS ARGENTINAS
# 619   1089438172  01/02/2023       WH MALVINAS ARGENTINAS
# 766   1089451953  02/02/2023  AVELLANEDA - C DISTRIBUCIÓN
# ...          ...         ...                          ...
# 8778  1089775292  17/02/2023  AVELLANEDA - C DISTRIBUCIÓN
# 8779  1089775513  17/02/2023  AVELLANEDA - C DISTRIBUCIÓN
# 8780  1089775540  17/02/2023  AVELLANEDA - C DISTRIBUCIÓN
# 8781  1089775762  17/02/2023  AVELLANEDA - C DISTRIBUCIÓN
# 8782  1089775771  17/02/2023  AVELLANEDA - C DISTRIBUCIÓN
#
# [745 rows x 3 columns]

# %%
# revisar el tipo de data de la seleccion
type(filtered_df[['NENVIO','FECHA','DESTINO']])
# Out:
# pandas.core.frame.DataFrame

# %%
# Agregar una columna al dataframe
df_17.head()
df_17['TOTAL'] = 0
df_17
# Out:
#           NENVIO       FECHA     REFERENCIA  REF_ADICIONAL OBSER1 OBSER2  \
# 0     1089280830  02/02/2023  000502482638R     82969368.0    NaN    NaN
# 1     1089304773  06/02/2023  000502483023R     82969763.0    NaN    NaN
# 2     1089337521  01/02/2023  000502483732R     82970536.0    NaN    NaN
# 3     1089337522  01/02/2023  000502483733R     82970537.0    NaN    NaN
# 4     1089337523  01/02/2023  000502483734R     82970538.0    NaN    NaN
# ...          ...         ...            ...            ...    ...    ...
# 8778  1089775292  17/02/2023     0082977669            NaN    NaN    NaN
# 8779  1089775513  17/02/2023     0082977636            NaN    NaN    NaN
# 8780  1089775540  17/02/2023     0082977675            NaN    NaN    NaN
# 8781  1089775762  17/02/2023     0082978028            NaN    NaN    NaN
# 8782  1089775771  17/02/2023     0082977536            NaN    NaN    NaN
#
#        CODREMI            CLIENTE                       ORIGEN  \
# ...

# %%
# Agregar una columna con array
# importar numpy
import numpy as np

# %%
# crear un array de 8783 elementos
total = np.arange(0,8783)

# %%
# tamaño del array
len(total)
# Out:
# 8783

# %%
# agregar columna con un array
df_17['TOTAL'] = total
df_17.head()
# Out:
#        NENVIO       FECHA     REFERENCIA  REF_ADICIONAL OBSER1 OBSER2  \
# 0  1089280830  02/02/2023  000502482638R     82969368.0    NaN    NaN
# 1  1089304773  06/02/2023  000502483023R     82969763.0    NaN    NaN
# 2  1089337521  01/02/2023  000502483732R     82970536.0    NaN    NaN
# 3  1089337522  01/02/2023  000502483733R     82970537.0    NaN    NaN
# 4  1089337523  01/02/2023  000502483734R     82970538.0    NaN    NaN
#
#     CODREMI            CLIENTE                  ORIGEN  \
# 0  60009400  ROFINA S.A.I.C.F.  WH MALVINAS ARGENTINAS
# 1  60009400  ROFINA S.A.I.C.F.  WH MALVINAS ARGENTINAS
# 2  60009400  ROFINA S.A.I.C.F.  WH MALVINAS ARGENTINAS
# 3  60009400  ROFINA S.A.I.C.F.  WH MALVINAS ARGENTINAS
# 4  60009400  ROFINA S.A.I.C.F.  WH MALVINAS ARGENTINAS
#
#                   DESTINO  ...  KEYTSV             SITUACION CENTRO_COSTO  \
# 0  WH MALVINAS ARGENTINAS  ...       6  PENDIENTE EN DESTINO       028142
# ...

# %%
 # crear valores aleatorios entre 1 y 100
total_random = np.random.randint(1,100,size=8783)
total_random2 = np.random.randint(1,100,size=8783)
df_17['TOTAL'] = total_random
df_17['TOTAL2'] = total_random2
df_17.head(2)
# Out:
#        NENVIO       FECHA     REFERENCIA  REF_ADICIONAL OBSER1 OBSER2  \
# 0  1089280830  02/02/2023  000502482638R     82969368.0    NaN    NaN
# 1  1089304773  06/02/2023  000502483023R     82969763.0    NaN    NaN
#
#     CODREMI            CLIENTE                  ORIGEN  \
# 0  60009400  ROFINA S.A.I.C.F.  WH MALVINAS ARGENTINAS
# 1  60009400  ROFINA S.A.I.C.F.  WH MALVINAS ARGENTINAS
#
#                   DESTINO  ...  CENTRO_COSTO  USUARIO_G FEC_MOBILE  \
# 0  WH MALVINAS ARGENTINAS  ...        028142   NPERAZZO        NaN
# 1  WH MALVINAS ARGENTINAS  ...        014676    MVARONE        NaN
#
#   FEC_MOBILE_2115 FEC_MOBILE_CDS CENTRO_COSTO_1  UCA TOTAL TOTAL2 TOTAL_FINAL
# 0             NaN            NaN         028142  NaN    95     19        14.0
# 1             NaN            NaN         014676  NaN    49     90        18.0
#
# [2 rows x 45 columns]

# %%
# crear valores decimales aleatorios

np.random.uniform(1,100, size=8783)
# Out:
# array([83.82806699, 84.90770011,  4.8659391 , ..., 84.4407412 ,
#        86.17346784, 79.21726881])

# %%
# selecciona una columna y calcula la suma total
df_17['TOTAL'].sum()
# Out:
# 441334

# %%
# contar cantidad de elementos
df_17['TOTAL'].count()
# Out:
# 8783

# %%
# promedio de todos los elementos
df_17['TOTAL'].mean()
# Out:
# 50.24866218831834

# %%
# calculamos la suma de una fila

df_17['TOTAL_FINAL'] = df_17['TOTAL'] + df_17['TOTAL2']

# %%
# calcular el promedio y asignarselo a una nueva columna

df_17['PROMEDIO'] = (df_17['TOTAL'] + df_17['TOTAL2'])/2
df_17.head(2)
df_17.round(2).head(2)
# Out:
#        NENVIO       FECHA     REFERENCIA  REF_ADICIONAL OBSER1 OBSER2  \
# 0  1089280830  02/02/2023  000502482638R     82969368.0    NaN    NaN
# 1  1089304773  06/02/2023  000502483023R     82969763.0    NaN    NaN
#
#     CODREMI            CLIENTE                  ORIGEN  \
# 0  60009400  ROFINA S.A.I.C.F.  WH MALVINAS ARGENTINAS
# 1  60009400  ROFINA S.A.I.C.F.  WH MALVINAS ARGENTINAS
#
#                   DESTINO  ...  USUARIO_G  FEC_MOBILE FEC_MOBILE_2115  \
# 0  WH MALVINAS ARGENTINAS  ...   NPERAZZO         NaN             NaN
# 1  WH MALVINAS ARGENTINAS  ...    MVARONE         NaN             NaN
#
#   FEC_MOBILE_CDS CENTRO_COSTO_1  UCA TOTAL TOTAL2 TOTAL_FINAL PROMEDIO
# 0            NaN         028142  NaN    95     19         114     57.0
# 1            NaN         014676  NaN    49     90         139     69.5
#
# [2 rows x 46 columns]

# %%
# contar los elementos de cualquier columna con mismo value

df_origen = df_17['SITUACION'] == 'PDTE.ORIGEN'
filtered_df = df_17[df_origen]
filtered_df['DESTINO'].value_counts()
# Out:
# AVELLANEDA - C DISTRIBUCIÓN    154
# WH MALVINAS ARGENTINAS          88
# CORDOBA                         64
# ROSARIO                         63
# BENAVIDEZ - C DISTRIBUCION      59
# MENDOZA                         52
# MAR DEL PLATA                   45
# SANTA FE                        39
# TANDIL                          36
# CORRIENTES                      34
# GUALEGUAYCHU                    30
# SAN JUAN                        28
# TUCUMAN                         12
# FLORIDA (LOG INVERSA ZN)         5
# LA RIOJA                         4
# VILLA MARIA                      4
# POSADAS                          4
# SALTA                            4
# JUJUY                            3
# RESISTENCIA                      2
# BAHIA BLANCA                     2
# COMODORO RIVADAVIA               2
# SAN LUIS                         2
# JUNIN                            1
# CONCORDIA                        1
# CDS USHUAIA                      1
# FORMOSA                          1
# ...

# %%
# contar los elementos de cualquier columna con mismo value y mostrar el porcentaje
filtered_df['DESTINO'].value_counts(normalize=True)
# Out:
# AVELLANEDA - C DISTRIBUCIÓN    0.206711
# WH MALVINAS ARGENTINAS         0.118121
# CORDOBA                        0.085906
# ROSARIO                        0.084564
# BENAVIDEZ - C DISTRIBUCION     0.079195
# MENDOZA                        0.069799
# MAR DEL PLATA                  0.060403
# SANTA FE                       0.052349
# TANDIL                         0.048322
# CORRIENTES                     0.045638
# GUALEGUAYCHU                   0.040268
# SAN JUAN                       0.037584
# TUCUMAN                        0.016107
# FLORIDA (LOG INVERSA ZN)       0.006711
# LA RIOJA                       0.005369
# VILLA MARIA                    0.005369
# POSADAS                        0.005369
# SALTA                          0.005369
# JUJUY                          0.004027
# RESISTENCIA                    0.002685
# BAHIA BLANCA                   0.002685
# COMODORO RIVADAVIA             0.002685
# SAN LUIS                       0.002685
# ...

# %%
# ordenar por columna
df_17.sort_values('TOTAL')

# %%
# ordenar descendiente por columna
df_17.sort_values('TOTAL',ascending=False)

# %%
# ordenar descendiente por multiples columnas
df_17.sort_values(['TOTAL', 'TOTAL2'],ascending=False)

# %%
# ordenar descendiente por multiples columnas y actualizar el dataframe
df_17.sort_values(['TOTAL', 'TOTAL2'],ascending=False, inplace=True)

# %%
# ordenar descendiente con una funcion key
df_17.sort_values('TOTAL',ascending=True,key= lambda col:col.str.lower())
